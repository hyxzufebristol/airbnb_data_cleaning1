# %%
import pandas as pd

# %%
df_listings = pd.read_csv('listings.csv')

# %%
#运行更多行的代码
pd.set_option ('display.max_rows', 100) 
pd.set_option ('display.max_columns', 100)
df_listings['name'].value_counts().head(100)
# Out:
# Royal Stays|Near Casino|Wifi|Kitchen|Laundry|Prime Location                    29
# 墨尔本东北区Bundoora温馨独栋别墅，房间干净整齐、设施齐全、交通方便、高速网络、高档床上用品！                             27
# Royal Stays|Full Kitchen|Washer & Dryer|WiFi & More                            26
# Home away from home                                                            15
# Domi Rentals - The Carlisle Apartments                                         14
# One Bedroom Apartment                                                          14
# 1 Bedroom Suite in Melbourne CBD                                               12
# Large Room in our Lovely Carlton Guest House                                   11
# Executive Room Next to Sydney Road                                             11
# Studio Apartment                                                               10
# Two Bedroom Apartment                                                           9
# ...

# %%
df_listings['price']
# Out:
# 0         $60.00
# 1         $31.00
# 2         $95.00
# 3         $99.00
# 4         $40.00
#           ...
# 20415    $265.00
# 20416     $50.00
# 20417    $188.00
# 20418     $24.00
# 20419     $96.00
# Name: price, Length: 20420, dtype: object

# %%
df_listings[df_listings.name=='Royal Stays|Near Casino|Wifi|Kitchen|Laundry|Prime Location']
# Out:
#              id                            listing_url       scrape_id  \
# 9279   24480685  https://www.airbnb.com/rooms/24480685  20200820034003
# 9280   24480723  https://www.airbnb.com/rooms/24480723  20200820034003
# 9281   24480752  https://www.airbnb.com/rooms/24480752  20200820034003
# 9282   24480783  https://www.airbnb.com/rooms/24480783  20200820034003
# 9283   24480871  https://www.airbnb.com/rooms/24480871  20200820034003
# 9284   24480957  https://www.airbnb.com/rooms/24480957  20200820034003
# 10377  27436647  https://www.airbnb.com/rooms/27436647  20200820034003
# 12441  31815564  https://www.airbnb.com/rooms/31815564  20200820034003
# 17963  41357010  https://www.airbnb.com/rooms/41357010  20200820034003
# 17965  41357334  https://www.airbnb.com/rooms/41357334  20200820034003
# 17966  41357373  https://www.airbnb.com/rooms/41357373  20200820034003
# 17967  41357393  https://www.airbnb.com/rooms/41357393  20200820034003
# ...

# %%
# remove '$' of 'price'
def format_price(price):
    return(float(price.replace('$','').replace(',','')))

df_listings['price_$'] = df_listings['price'].apply(format_price) 
df_listings[['price','price_$']].head()
# Out:
#     price  price_$
# 0  $60.00     60.0
# 1  $31.00     31.0
# 2  $95.00     95.0
# 3  $99.00     99.0
# 4  $40.00     40.0

# %%
# (homes' names of 100 highest profit_per_month)

df_listings['profit_per_month'] = df_listings['price_$'] * df_listings['reviews_per_month']
df_listings = df_listings.sort_values(by=['profit_per_month'],ascending=False)
df_listings[['name','host_name','price_$','number_of_reviews','reviews_per_month','profit_per_month']].head(100)
# Out:
#                                                     name  \
# 10037  ⭐CozyOneBDR,wifi,pool Close Uni,Hospital,QVMarket
# 6406         Cosy Apt with luxury Tempur bed on Lygon St
# 10974     Cosy stay with luxury Madison  bed on Lygon St
# 11654    ⭐2BR2BTH Cozy apartmentFreeparking 200米到盒子山，近一切
# 12456  ⭐4Bedder Beautiful Comfy Family House with The...
# 13379  ⭐4bedder comfty house close to Stud Park SC, LAKE
# 11054            Be on Cloud9 - Melb Central Lux 3BR Apt
# 14385  ⭐5Bedder3.5Bath Luxury House walking to Westfield
# 17368           ⭐3 bedder Cozy house with Centre Cooling
# 13988  ⭐3Bedder3.5bath Townhouse @DoncasterCloseWestf...
# 9634     Springfield Country Retreat at Lysterfield Lake
# 16738  ⭐4Bedder Beautiful Comfy Family House with The...
# 14819            Luxury waterfront lifestyle in Dockland
# 7324                                   Monash University
# 17491              1 Bedroom Apt - Next to The Glen Mall
# ...

# %%
# (homes' names of 100 highest profit_per_month)

df_listings['profit_sum'] = df_listings['price'] * df_listings['number_of_reviews']
df_listings = df_listings.sort_values(by=['profit_sum'],ascending=False)
df_listings[['name','host_name','price','number_of_reviews','reviews_per_month','profit_per_month','profit_sum']].head(100)
# Out:
#                                                     name           host_name  \
# 1679                the beach retreat | summer sale -30%               Nirav
# 8664   Luxury inner-Melb 5 brm home, close to everything            Jeanette
# 10888          Gravity Tower - 2502 - Adam Klein - Princ                Adam
# 2964                        Contemporary home in Bayside            Julianne
# 12435  Healesville Garden Homestead B&B (6 Bedroom Ho...            Michelle
# 7191   Caulfield South - double storey & basketball c...                 Rob
# 16460   Box Hill Central Sky One 2BR/2BA APT A *Pool&Gym            LaMaison
# 265     Adorable Chalet Tucked Away in Bohemian St Kilda               Vicki
# 4596        Modern 1 bedroom Soutbank, entire apartment.               David
# 2493   Laneway Loft - Boutique styling in a gem location                 Ray
# 7302               ❤ Docklands Harbour ❤ Modern APT+WIFI                Lisa
# ...

# %%
df_listings = pd.read_csv('listings.csv')

# %%
df_listings[df_listings.name=='Royal Stays|Near Casino|Wifi|Kitchen|Laundry|Prime Location']
# Out:
#              id                            listing_url       scrape_id  \
# 9279   24480685  https://www.airbnb.com/rooms/24480685  20200820034003
# 9280   24480723  https://www.airbnb.com/rooms/24480723  20200820034003
# 9281   24480752  https://www.airbnb.com/rooms/24480752  20200820034003
# 9282   24480783  https://www.airbnb.com/rooms/24480783  20200820034003
# 9283   24480871  https://www.airbnb.com/rooms/24480871  20200820034003
# 9284   24480957  https://www.airbnb.com/rooms/24480957  20200820034003
# 10377  27436647  https://www.airbnb.com/rooms/27436647  20200820034003
# 12441  31815564  https://www.airbnb.com/rooms/31815564  20200820034003
# 17963  41357010  https://www.airbnb.com/rooms/41357010  20200820034003
# 17965  41357334  https://www.airbnb.com/rooms/41357334  20200820034003
# 17966  41357373  https://www.airbnb.com/rooms/41357373  20200820034003
# 17967  41357393  https://www.airbnb.com/rooms/41357393  20200820034003
# ...

# %%
pd.set_option ('display.max_rows', 1000) 
pd.set_option ('display.max_columns', 1000)
df_listings['host_location'].value_counts().head(1000)
#发现Australia的房源最多
# Out:
# Melbourne, Victoria, Australia                                                                                                                                                                                                                                     7351
# AU                                                                                                                                                                                                                                                                 2843
# Victoria, Australia                                                                                                                                                                                                                                                2201
# ...

# %%
df_listings0 = pd.read_csv('Sample 2_Airbnb_listings.csv')

# %%
pd.set_option ('display.max_rows', 1000) 
pd.set_option ('display.max_columns', 1000)
df_listings0['host_location'].value_counts().head(1000)
# Out:
# London, England, United Kingdom                                                      12330
# GB                                                                                    3822
# England, United Kingdom                                                               3737
# London, United Kingdom                                                                2353
# London                                                                                1831
# Greater London, England, United Kingdom                                                498
# United Kingdom                                                                         233
# London, UK                                                                             196
# london                                                                                 104
# Burgas, Burgas, Bulgaria                                                               104
# ...

# %%
#check price
df_listings['price'].value_counts().head(100)
# Out:
# $100.00    600
# $50.00     597
# $60.00     522
# $80.00     499
# $120.00    450
# $150.00    447
# $70.00     441
# $90.00     431
# $45.00     363
# $40.00     350
# $65.00     344
# $75.00     343
# $99.00     317
# $110.00    314
# $55.00     302
# $85.00     286
# $200.00    260
# $35.00     246
# $95.00     231
# $180.00    210
# $140.00    208
# $130.00    203
# $250.00    184
# $30.00     172
# $125.00    170
# $160.00    154
# $89.00     153
# $49.00     150
# $79.00     149
# $300.00    142
# $135.00    141
# $129.00    135
# $69.00     132
# $115.00    126
# $105.00    123
# $59.00     119
# $25.00     116
# $119.00    113
# $38.00     108
# $68.00     107
# $145.00    106
# $39.00     105
# $37.00     104
# $149.00    102
# $58.00     101
# $109.00     98
# $220.00     98
# $98.00      98
# $170.00     94
# $48.00      91
# $139.00     91
# $92.00      88
# $83.00      88
# $72.00      86
# $78.00      83
# $190.00     82
# $88.00      81
# $175.00     81
# ...

# %%
df_listings['price']
# Out:
# 0         $60.00
# 1         $31.00
# 2         $95.00
# 3         $99.00
# 4         $40.00
#           ...
# 20415    $265.00
# 20416     $50.00
# 20417    $188.00
# 20418     $24.00
# 20419     $96.00
# Name: price, Length: 20420, dtype: object

# %%
df_listings = pd.read_csv('listings-summary.csv')

# %%
df_listings['price']
# Out:
# 0         60
# 1         31
# 2         95
# 3         99
# 4         40
#         ...
# 20415    265
# 20416     50
# 20417    188
# 20418     24
# 20419     96
# Name: price, Length: 20420, dtype: int64

# %%
#check price
df_listings['price'].value_counts().head(100)
# Out:
# 100    602
# 50     599
# 60     523
# 80     499
# 120    450
# 150    448
# 70     441
# 90     432
# 45     363
# 40     350
# 65     345
# 75     343
# 99     319
# 110    314
# 55     303
# 85     290
# 200    260
# 35     246
# 95     234
# 140    211
# 180    210
# 130    205
# 250    184
# 30     172
# 125    170
# 160    154
# 89     154
# 49     151
# 79     149
# 135    142
# 300    142
# 129    137
# 69     134
# 115    127
# 105    123
# 59     120
# 25     116
# 119    116
# 38     108
# 68     108
# 145    106
# 39     106
# 37     104
# 149    103
# 58     103
# 98     100
# 220     99
# 109     98
# 170     96
# 48      92
# 83      92
# 139     92
# 92      90
# 72      89
# 78      84
# 88      83
# 175     82
# 190     82
# 500     77
# 350     76
# 66      76
# 42      75
# 159     74
# 138     73
# 199     72
# 155     70
# 165     70
# 32      70
# 96      68
# 52      68
# 34      66
# 400     66
# 93      65
# 118     65
# 62      64
# 94      64
# ...
